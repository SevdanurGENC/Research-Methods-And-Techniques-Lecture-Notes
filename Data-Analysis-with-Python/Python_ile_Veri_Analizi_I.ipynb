# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
veriSeti = {'İsim':pd.Series(['Ada','Cem','Sibel','Ahmet','Mehmet','Ali','Veli','Ayşe','Hüseyin','Necmi','Nalan','Namık']),
          'Meslek':pd.Series(['işçi','işçi','memur','serbest','serbest',None,None,'sigortacı','işsiz',None,None,'memur']),
          'Tarih':pd.Series(['11.11.2010','11.11.2010','11.11.2010','18.11.2011','18.11.2011',None,None,None,'11.11.2010',None,'18.11.2011','18.11.2011']),          
          'Yaş':pd.Series([21, 24, 25, 44, 31, 27, 35, 33, 42, 29, 41, 43]),
          'ÇocukSayısı':pd.Series([None, None, None, None, None, 1, 2, 0, None, None, None, None]),
          'Puan':pd.Series([89, 87, 77, 55, 70, 79, 73, 79, 54, 92, 61, 69])}
df = pd.DataFrame(veriSeti)
df
# Out:
#        İsim     Meslek       Tarih  Yaş  ÇocukSayısı  Puan
# 0       Ada       işçi  11.11.2010   21          NaN    89
# 1       Cem       işçi  11.11.2010   24          NaN    87
# 2     Sibel      memur  11.11.2010   25          NaN    77
# 3     Ahmet    serbest  18.11.2011   44          NaN    55
# 4    Mehmet    serbest  18.11.2011   31          NaN    70
# 5       Ali       None        None   27          1.0    79
# 6      Veli       None        None   35          2.0    73
# 7      Ayşe  sigortacı        None   33          0.0    79
# 8   Hüseyin      işsiz  11.11.2010   42          NaN    54
# 9     Necmi       None        None   29          NaN    92
# 10    Nalan       None  18.11.2011   41          NaN    61
# 11    Namık      memur  18.11.2011   43          NaN    69

# %%
df.head()
# Out:
#      İsim   Meslek       Tarih  Yaş  ÇocukSayısı  Puan
# 0     Ada     işçi  11.11.2010   21          NaN    89
# 1     Cem     işçi  11.11.2010   24          NaN    87
# 2   Sibel    memur  11.11.2010   25          NaN    77
# 3   Ahmet  serbest  18.11.2011   44          NaN    55
# 4  Mehmet  serbest  18.11.2011   31          NaN    70

# %%
df.tail()
# Out:
#        İsim     Meslek       Tarih  Yaş  ÇocukSayısı  Puan
# 7      Ayşe  sigortacı        None   33          0.0    79
# 8   Hüseyin      işsiz  11.11.2010   42          NaN    54
# 9     Necmi       None        None   29          NaN    92
# 10    Nalan       None  18.11.2011   41          NaN    61
# 11    Namık      memur  18.11.2011   43          NaN    69

# %%
df.sample(5)
# Out:
#      İsim   Meslek       Tarih  Yaş  ÇocukSayısı  Puan
# 9   Necmi     None        None   29          NaN    92
# 10  Nalan     None  18.11.2011   41          NaN    61
# 0     Ada     işçi  11.11.2010   21          NaN    89
# 2   Sibel    memur  11.11.2010   25          NaN    77
# 3   Ahmet  serbest  18.11.2011   44          NaN    55

# %%
df.shape
# Out:
# (12, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   İsim         12 non-null     object
#  1   Meslek       8 non-null      object
#  2   Tarih        8 non-null      object
#  3   Yaş          12 non-null     int64
#  4   ÇocukSayısı  3 non-null      float64
#  5   Puan         12 non-null     int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 704.0+ bytes

# %%
df['Yaş']
# Out:
# 0     21
# 1     24
# 2     25
# 3     44
# 4     31
# 5     27
# 6     35
# 7     33
# 8     42
# 9     29
# 10    41
# 11    43
# Name: Yaş, dtype: int64

# %%
df['İsim'][:5]
# Out:
# 0       Ada
# 1       Cem
# 2     Sibel
# 3     Ahmet
# 4    Mehmet
# Name: İsim, dtype: object

# %%
df[['Yaş','İsim']]
# Out:
#     Yaş     İsim
# 0    21      Ada
# 1    24      Cem
# 2    25    Sibel
# 3    44    Ahmet
# 4    31   Mehmet
# 5    27      Ali
# 6    35     Veli
# 7    33     Ayşe
# 8    42  Hüseyin
# 9    29    Necmi
# 10   41    Nalan
# 11   43    Namık

# %%
df[(df['Yaş']>30) & (df['Puan']>50)]
# Out:
#        İsim     Meslek       Tarih  Yaş  ÇocukSayısı  Puan
# 3     Ahmet    serbest  18.11.2011   44          NaN    55
# 4    Mehmet    serbest  18.11.2011   31          NaN    70
# 6      Veli       None        None   35          2.0    73
# 7      Ayşe  sigortacı        None   33          0.0    79
# 8   Hüseyin      işsiz  11.11.2010   42          NaN    54
# 10    Nalan       None  18.11.2011   41          NaN    61
# 11    Namık      memur  18.11.2011   43          NaN    69

# %%
df[(df['Meslek']=='işçi') | (df['Puan']>90)]
# Out:
#     İsim Meslek       Tarih  Yaş  ÇocukSayısı  Puan
# 0    Ada   işçi  11.11.2010   21          NaN    89
# 1    Cem   işçi  11.11.2010   24          NaN    87
# 9  Necmi   None        None   29          NaN    92

# %%
df_filtered = df.query('Yaş>30 & Puan>50')
df_filtered
# Out:
#        İsim     Meslek       Tarih  Yaş  ÇocukSayısı  Puan
# 3     Ahmet    serbest  18.11.2011   44          NaN    55
# 4    Mehmet    serbest  18.11.2011   31          NaN    70
# 6      Veli       None        None   35          2.0    73
# 7      Ayşe  sigortacı        None   33          0.0    79
# 8   Hüseyin      işsiz  11.11.2010   42          NaN    54
# 10    Nalan       None  18.11.2011   41          NaN    61
# 11    Namık      memur  18.11.2011   43          NaN    69

# %%
df.sort_values('Puan', axis=0, ascending=False)
# Out:
#        İsim     Meslek       Tarih  Yaş  ÇocukSayısı  Puan
# 9     Necmi       None        None   29          NaN    92
# 0       Ada       işçi  11.11.2010   21          NaN    89
# 1       Cem       işçi  11.11.2010   24          NaN    87
# 5       Ali       None        None   27          1.0    79
# 7      Ayşe  sigortacı        None   33          0.0    79
# 2     Sibel      memur  11.11.2010   25          NaN    77
# 6      Veli       None        None   35          2.0    73
# 4    Mehmet    serbest  18.11.2011   31          NaN    70
# 11    Namık      memur  18.11.2011   43          NaN    69
# 10    Nalan       None  18.11.2011   41          NaN    61
# 3     Ahmet    serbest  18.11.2011   44          NaN    55
# 8   Hüseyin      işsiz  11.11.2010   42          NaN    54

# %%
df[(df['Yaş']>30) & (df['Puan']>50)].sort_values('Puan', axis=0, ascending=False)
# Out:
#        İsim     Meslek       Tarih  Yaş  ÇocukSayısı  Puan
# 7      Ayşe  sigortacı        None   33          0.0    79
# 6      Veli       None        None   35          2.0    73
# 4    Mehmet    serbest  18.11.2011   31          NaN    70
# 11    Namık      memur  18.11.2011   43          NaN    69
# 10    Nalan       None  18.11.2011   41          NaN    61
# 3     Ahmet    serbest  18.11.2011   44          NaN    55
# 8   Hüseyin      işsiz  11.11.2010   42          NaN    54

# %%
df.groupby('Meslek').size()
# Out:
# Meslek
# işsiz        1
# işçi         2
# memur        2
# serbest      2
# sigortacı    1
# dtype: int64

# %%
df['Meslek'] = df['Meslek'].astype(str)
df.groupby('Meslek').size()
# Out:
# Meslek
# None         4
# işsiz        1
# işçi         2
# memur        2
# serbest      2
# sigortacı    1
# dtype: int64

# %%
df.groupby('Meslek')['Puan'].apply(lambda x: np.mean(x))
# Out:
# Meslek
# None         76.25
# işsiz        54.00
# işçi         88.00
# memur        73.00
# serbest      62.50
# sigortacı    79.00
# Name: Puan, dtype: float64

# %%
df['Puan'].median()
# Out:
# 75.0

# %%
df['Puan'].mean()
# Out:
# 73.75

# %%
df.mean(axis=0, skipna=True)
# Out:
# <ipython-input-28-dc02baa7f1e5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean(axis=0, skipna=True)
# Yaş            32.916667
# ÇocukSayısı     1.000000
# Puan           73.750000
# dtype: float64

# %%
df['Puan'].std()
# Out:
# 12.606816338069583

# %%
df['Puan'].std() ** 2
# Out:
# 158.9318181818182

# %%
df.cov()
# Out:
# <ipython-input-31-6f98a29763d5>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#                    Yaş  ÇocukSayısı        Puan
# Yaş          64.992424          1.0  -87.295455
# ÇocukSayısı   1.000000          1.0   -3.000000
# Puan        -87.295455         -3.0  158.931818

# %%
df.corr()
# Out:
# <ipython-input-32-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   Yaş  ÇocukSayısı      Puan
# Yaş          1.000000     0.240192 -0.858924
# ÇocukSayısı  0.240192     1.000000 -0.866025
# Puan        -0.858924    -0.866025  1.000000

# %%
df.plot(x='Yaş', y='Puan', style='*')
# Out:
# <Axes: xlabel='Yaş'>

# %%
corr = df.corr()
sns.heatmap(corr, xticklabels = corr.columns.values, 
            yticklabels=corr.columns.values)
# Out:
# <ipython-input-37-a4be6c413198>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# <Axes: >
