# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#https://www.kaggle.com/code/ahmetokanyilmaz/pandas-ile-ke-if-i-veri-analizi/notebook
salaries = pd.read_csv('Data Science Jobs Salaries.csv')

# %%
salaries.head()  # ilgili veri setinin ilk 5 gözlemini çıktı olarak verir.
# Out:
#   work_year experience_level employment_type                  job_title  \
# 0     2021e               EN              FT    Data Science Consultant
# 1      2020               SE              FT             Data Scientist
# 2     2021e               EX              FT       Head of Data Science
# 3     2021e               EX              FT               Head of Data
# 4     2021e               EN              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   54000             EUR          64369                 DE            50
# 1   60000             EUR          68428                 GR           100
# 2   85000             USD          85000                 RU             0
# 3  230000             USD         230000                 RU            50
# 4  125000             USD         125000                 US           100
#
#   company_location company_size
# 0               DE            L
# 1               US            L
# 2               RU            M
# 3               RU            L
# 4               US            S

# %%
salaries.tail()  # ilgili veri setinin son 5 gözlemini çıktı olarak verir.
# Out:
#     work_year experience_level employment_type                 job_title  \
# 240      2020               SE              FT            Data Scientist
# 241     2021e               MI              FT  Principal Data Scientist
# 242      2020               EN              FT            Data Scientist
# 243      2020               EN              CT     Business Data Analyst
# 244     2021e               SE              FT      Data Science Manager
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 240   412000             USD         412000                 US           100
# 241   151000             USD         151000                 US           100
# 242   105000             USD         105000                 US           100
# 243   100000             USD         100000                 US           100
# 244  7000000             INR          94917                 IN            50
#
#     company_location company_size
# 240               US            L
# 241               US            L
# 242               US            S
# 243               US            L
# 244               IN            L

# %%
salaries.sample()
# Out:
#     work_year experience_level employment_type             job_title  salary  \
# 116     2021e               SE              CT  Staff Data Scientist  105000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 116             USD         105000                 US           100
#
#     company_location company_size
# 116               US            M

# %%
salaries.sort_values(by='salary_in_usd', ascending=False).head()
# Out:
#     work_year experience_level employment_type  \
# 191     2021e               EX              FT
# 63      2021e               MI              FT
# 6        2020               MI              FT
# 237     2021e               MI              FT
# 162     2021e               EX              CT
#
#                               job_title  salary salary_currency  \
# 191             Principal Data Engineer  600000             USD
# 63               Financial Data Analyst  450000             USD
# 6                    Research Scientist  450000             USD
# 237  Applied Machine Learning Scientist  423000             USD
# 162            Principal Data Scientist  416000             USD
#
#      salary_in_usd employee_residence  remote_ratio company_location  \
# 191         600000                 US           100               US
# 63          450000                 US           100               US
# 6           450000                 US             0               US
# 237         423000                 US            50               US
# 162         416000                 US           100               US
#
#     company_size
# 191            L
# 63             L
# 6              M
# 237            L
# 162            S

# %%
salaries.sort_values(by=['salary_in_usd', 'company_size'], ascending=False).head()
# Out:
#     work_year experience_level employment_type  \
# 191     2021e               EX              FT
# 6        2020               MI              FT
# 63      2021e               MI              FT
# 237     2021e               MI              FT
# 162     2021e               EX              CT
#
#                               job_title  salary salary_currency  \
# 191             Principal Data Engineer  600000             USD
# 6                    Research Scientist  450000             USD
# 63               Financial Data Analyst  450000             USD
# 237  Applied Machine Learning Scientist  423000             USD
# 162            Principal Data Scientist  416000             USD
#
#      salary_in_usd employee_residence  remote_ratio company_location  \
# 191         600000                 US           100               US
# 6           450000                 US             0               US
# 63          450000                 US           100               US
# 237         423000                 US            50               US
# 162         416000                 US           100               US
#
#     company_size
# 191            L
# 6              M
# 63             L
# 237            L
# 162            S

# %%
salaries.groupby('company_location').size().sort_values(ascending=False).head(10)
# Out:
# company_location
# US    108
# DE     19
# IN     17
# GB     16
# FR     11
# CA     11
# ES      7
# JP      4
# TR      3
# DK      3
# dtype: int64

# %%
salaries.shape
# Out:
# (245, 11)

# %%
salaries.size
# Out:
# 2695

# %%
salaries.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           245 non-null    object
#  1   experience_level    245 non-null    object
#  2   employment_type     245 non-null    object
#  3   job_title           245 non-null    object
#  4   salary              245 non-null    int64
#  5   salary_currency     245 non-null    object
#  6   salary_in_usd       245 non-null    int64
#  7   employee_residence  245 non-null    object
#  8   remote_ratio        245 non-null    int64
#  9   company_location    245 non-null    object
#  10  company_size        245 non-null    object
# dtypes: int64(3), object(8)
# memory usage: 21.2+ KB

# %%
salaries.select_dtypes(include = [int, float]).head()
# Out:
#    salary  salary_in_usd  remote_ratio
# 0   54000          64369            50
# 1   60000          68428           100
# 2   85000          85000             0
# 3  230000         230000            50
# 4  125000         125000           100

# %%
salaries.select_dtypes([int, float]).columns
# Out:
# Index(['salary', 'salary_in_usd', 'remote_ratio'], dtype='object')

# %%
salaries.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
salaries.describe().T
# Out:
#                count           mean           std     min      25%       50%  \
# salary         245.0  502541.812245  2.276230e+06  4000.0  60000.0  103000.0
# salary_in_usd  245.0   99868.012245  8.398333e+04  2876.0  45896.0   81000.0
# remote_ratio   245.0      69.183673  3.759342e+01     0.0     50.0     100.0
#
#                     75%         max
# salary         174000.0  30400000.0
# salary_in_usd  130000.0    600000.0
# remote_ratio      100.0       100.0

# %%
salaries['experience_level'].nunique()
# Out:
# 4

# %%
salaries['experience_level'].unique()
# Out:
# array(['EN', 'SE', 'EX', 'MI'], dtype=object)

# %%
salaries.corr()
# Out:
# <ipython-input-26-feaa521abdb1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   salaries.corr()
#                  salary  salary_in_usd  remote_ratio
# salary         1.000000      -0.087365     -0.004775
# salary_in_usd -0.087365       1.000000      0.171240
# remote_ratio  -0.004775       0.171240      1.000000

# %%
#Tekrarlayan değerler yerine sadece ilişkili değerleri görebilmek için korelasyon matrisini üçgen matrise çevirebiliriz.
import numpy as np
cor = pd.DataFrame(np.tril(salaries.corr().values), index=salaries.corr().index, columns=salaries.corr().columns).round(3)
cor = cor.iloc[:,:-1]
cor.drop(cor.head(1).index, inplace=True) 
cor.replace(to_replace=[0,1], value='', inplace=True)
# Out:
# <ipython-input-29-6c9a58145dea>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor = pd.DataFrame(np.tril(salaries.corr().values), index=salaries.corr().index, columns=salaries.corr().columns).round(3)

# %%
cor
# Out:
#                salary salary_in_usd
# salary_in_usd  -0.087
# remote_ratio   -0.005         0.171

# %%
sns.countplot(x='job_title', data=salaries)
plt.ylabel("Toplam", size=20)
plt.xlabel('Meslek', size=20)
plt.xticks(rotation=90)
plt.title("Mesleklerin Toplam Sayıları", size=20);

# %%
# Mesleklerin ortalama kazançlarına grafikte bakabiliriz.
sns.set()
job_salary_usd = salaries[['job_title', 'salary_in_usd']]
job_salary_usd  = salaries.groupby('job_title').agg({'salary_in_usd': 'mean'}).sort_values('salary_in_usd', ascending=False).reset_index()
fig = plt.figure(figsize=(14,12))
sns.barplot(x='job_title',
            y='salary_in_usd',
            data=job_salary_usd,
            ci=None)
plt.ylabel("Ortalama Maaş", size=20)
plt.xlabel('Meslek', size=20)
plt.xticks(rotation=90)
plt.title("Mesleklerin Ortalama Maaşları (USD)", size=25);
# Out:
# <ipython-input-33-171bb4449b9f>:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='job_title',

# %%
# Numeric değişkenlerin korelasyonunun ısı haritasıyla gösterimi
sns.heatmap(salaries.corr());
# Out:
# <ipython-input-34-b7592b1a1e77>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(salaries.corr());

# %%
sns.pairplot(salaries)

# %%
sns.displot(x='experience_level', data=salaries)

# %%
salaries.boxplot('salary_in_usd')
# Out:
# <Axes: >
